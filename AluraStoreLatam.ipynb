# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinbonillamontesdeoca/Amigo-Secreto/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:,.0f}'.format
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tiendas = {
    'tienda': tienda,
    'tienda2': tienda2,
    'tienda3': tienda3,
    'tienda4': tienda4
}

tienda.head()
# Out:
#             Producto Categoría del Producto  Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos 164,300           6,900
# 1    Mesa de comedor                Muebles 192,300           8,400
# 2      Juego de mesa               Juguetes 209,600          15,900
# 3         Microondas      Electrodomésticos 757,500          41,000
# 4   Silla de oficina                Muebles 335,200          20,200
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas  lat  lon
# 0  Tarjeta de crédito                   8    5  -74
# 1  Tarjeta de crédito                   4    6  -76
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
for nombre, df in tiendas.items():
    print(f"\n=== Exploración de {nombre} ===")
    display(df.head())
    display(df.info())
    display(df.describe(include='all'))
    print("Valores nulos por columna:")
    print(df.isnull().sum())
# Out:
# === Exploración de tienda ===
#             Producto Categoría del Producto  Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos 164,300           6,900
# 1    Mesa de comedor                Muebles 192,300           8,400
# 2      Juego de mesa               Juguetes 209,600          15,900
# 3         Microondas      Electrodomésticos 757,500          41,000
# 4   Silla de oficina                Muebles 335,200          20,200
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas  lat  lon
# 0  Tarjeta de crédito                   8    5  -74
# ...

# %%
ingresos = {nombre: df['Precio'].sum() for nombre, df in tiendas.items()}
ingresos_df = pd.DataFrame(list(ingresos.items()), columns=['Tienda', 'Ingreso Total (COP)'])
print("\n=== Ingresos Totales por Tienda ===")
display(ingresos_df)
plt.figure(figsize=(8,5))
plt.bar(ingresos_df['Tienda'], ingresos_df['Ingreso Total (COP)'])
plt.title('Ingreso Total por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingreso Total (COP)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# === Ingresos Totales por Tienda ===
#     Tienda  Ingreso Total (COP)
# 0   tienda        1,150,880,400
# 1  tienda2        1,116,343,500
# 2  tienda3        1,098,019,600
# 3  tienda4        1,038,375,700

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_categoria = {}
for nombre, df in tiendas.items():
    conteo = df['Categoría del Producto'].value_counts()
    ventas_categoria[nombre] = conteo

# %%
ventas_cat = {nombre: df['Categoría del Producto'].value_counts() for nombre, df in tiendas.items()}
ventas_cat_df = pd.DataFrame(ventas_cat).fillna(0).astype(int)
print("\n=== Ventas por Categoría por Tienda ===")
display(ventas_cat_df)
ventas_cat_df.plot(kind='bar', figsize=(10,6))
plt.title('Ventas por Categoría por Tienda')
plt.xlabel('Categoría')
plt.ylabel('Ventas')
plt.xticks(rotation=45)
plt.legend(title='Tienda')
plt.tight_layout()
plt.show()
# Out:
# === Ventas por Categoría por Tienda ===
#                          tienda  tienda2  tienda3  tienda4
# Categoría del Producto
# Artículos para el hogar     171      181      177      201
# Deportes y diversión        284      275      277      277
# Electrodomésticos           312      305      278      254
# Electrónicos                448      422      451      451
# Instrumentos musicales      182      224      177      170
# Juguetes                    324      313      315      338
# Libros                      173      197      185      187
# Muebles                     465      442      499      480

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calif = {nombre: df['Calificación'].mean() for nombre, df in tiendas.items()}
calif_df = pd.DataFrame(list(calif.items()), columns=['Tienda', 'Calificación Promedio'])
calif_df['Calificación Promedio'] = calif_df['Calificación Promedio'].round(2)
print("\n=== Calificación Promedio por Tienda ===")
display(calif_df)
plt.figure(figsize=(8,5))
plt.bar(calif_df['Tienda'], calif_df['Calificación Promedio'])
plt.title('Calificación Promedio por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.ylim(0,5)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# === Calificación Promedio por Tienda ===
#     Tienda  Calificación Promedio
# 0   tienda                      4
# 1  tienda2                      4
# 2  tienda3                      4
# 3  tienda4                      4

# %%
misma_valoracion = calif_df['Calificación Promedio'].nunique() == 1
print(f"\n¿Todas las tiendas tienen la misma calificación promedio? {misma_valoracion}")
print(f"Valores únicos de calificación promedio: {list(calif_df['Calificación Promedio'].unique())}")
# Out:
# ¿Todas las tiendas tienen la misma calificación promedio? False
# Valores únicos de calificación promedio: [np.float64(3.98), np.float64(4.04), np.float64(4.05), np.float64(4.0)]

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
print("\n=== Top 5 Productos más vendidos por Tienda ===")
top5 = {}
for nombre, df in tiendas.items():
    top5[nombre] = df['Producto'].value_counts().head(5)
    print(f"\n{nombre}")
    display(top5[nombre])
    plt.figure(figsize=(6,4))
    top5[nombre].plot(kind='bar')
    plt.title(f'Top 5 Productos - {nombre}')
    plt.xlabel('Producto')
    plt.ylabel('Ventas')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# === Top 5 Productos más vendidos por Tienda ===
#
# tienda
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# tienda2
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# tienda3
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64
# tienda4
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64

# %%
print("\n=== Top 5 Productos menos vendidos por Tienda ===")
bottom5 = {}
for nombre, df in tiendas.items():
    bottom5[nombre] = df['Producto'].value_counts().tail(5)
    print(f"\n{nombre}")
    display(bottom5[nombre])
    plt.figure(figsize=(6,4))
    bottom5[nombre].plot(kind='bar')
    plt.title(f'5 Productos Menos Vendidos - {nombre}')
    plt.xlabel('Producto')
    plt.ylabel('Ventas')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# === Top 5 Productos menos vendidos por Tienda ===
#
# tienda
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64
# tienda2
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64
# tienda3
# Producto
# Guitarra eléctrica         38
# Set de vasos               36
# Mochila                    36
# Microondas                 36
# Bloques de construcción    35
# Name: count, dtype: int64
# tienda4
# Producto
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio = {nombre: df['Costo de envío'].mean() for nombre, df in tiendas.items()}
envio_prom_df = pd.DataFrame(list(envio_promedio.items()), columns=['Tienda', 'Costo Envío Promedio (COP)'])
print("\n=== Comparación de Costo de Envío Promedio entre Tiendas ===")
display(envio_prom_df)
plt.figure(figsize=(8,5))
plt.bar(envio_prom_df['Tienda'], envio_prom_df['Costo Envío Promedio (COP)'])
plt.title('Comparación de Costo de Envío Promedio entre Tiendas')
plt.xlabel('Tienda')
plt.ylabel('Costo Envío Promedio (COP)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# === Comparación de Costo de Envío Promedio entre Tiendas ===
#     Tienda  Costo Envío Promedio (COP)
# 0   tienda                      26,019
# 1  tienda2                      25,216
# 2  tienda3                      24,806
# 3  tienda4                      23,459

# %% [markdown]
# # 6. Graficos Resumen

# %% [markdown]
# 9.1 Gráfico de Líneas: Ingresos Totales por Tienda (ordenado)

# %%
ingresos_ordenados = ingresos_df.sort_values('Ingreso Total (COP)')
plt.figure(figsize=(8,5))
plt.plot(ingresos_ordenados['Tienda'], ingresos_ordenados['Ingreso Total (COP)'], marker='o')
plt.title('Ingresos Totales por Tienda (Línea)')
plt.xlabel('Tienda')
plt.ylabel('Ingreso Total (COP)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 9.2 Gráfico de Pastel: Distribución de Categorías de la Tienda con más Ventas (Tienda Top)

# %%
tienda_top = ingresos_df.loc[ingresos_df['Ingreso Total (COP)'].idxmax(), 'Tienda']
cat_top = ventas_cat_df[tienda_top]
plt.figure(figsize=(6,6))
plt.pie(cat_top, labels=cat_top.index, autopct='%1.1f%%', startangle=140)
plt.title(f'Distribución de Categorías - {tienda_top}')
plt.tight_layout()
plt.show()

# %% [markdown]
# 9.3 Gráfico de Dispersión: Precio vs Calificación de Todas las Tiendas

# %%
ingreso_por_calif = df_concat.groupby('Calificación')['Precio'].sum().sort_index()
plt.figure(figsize=(8,5))
ingreso_por_calif.plot(kind='line', marker='o')
plt.title('Ingreso Total por Calificación')
plt.xlabel('Calificación')
plt.ylabel('Ingreso Total (COP)')
plt.xticks(ingreso_por_calif.index)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Exploración Geográfica de Ventas (Opcional)

# %% [markdown]
# Concatenar datos incluyendo etiqueta de tienda

# %%
df_geo = pd.concat([df.assign(Tienda=nombre) for nombre, df in tiendas.items()], ignore_index=True)

# %% [markdown]
# 8.1 Mapa de Dispersión de Ventas por Ubicación

# %%
plt.figure(figsize=(8,6))
for nombre, grupo in df_geo.groupby('Tienda'):
    plt.scatter(grupo['lon'], grupo['lat'], label=nombre, alpha=0.5)
plt.title('Mapa de Dispersión de Ventas por Ubicación')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 8.2 Heatmap de Densidad de Ventas

# %%
plt.figure(figsize=(8,6))
plt.hist2d(df_geo['lon'], df_geo['lat'], bins=(50,50), cmap='hot')
plt.title('Mapa de Calor de Ventas')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.colorbar(label='Número de Ventas')
plt.tight_layout()
plt.show()
